# %% [markdown]
# #### This is to show images created by Tableau saved to a local machine

# %%
import os
from PIL import Image

folder = r'D:\Github\5300\Project'
pics = ['County vs price per sqft.png', 'Year built vs price per sqft.png', 'Home type vs price per sqft.png']
pics = [os.path.join(folder, pic) for pic in pics]

# %%
Image.open(pics[0])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=963x537 at 0x214F9368790>

# %% [markdown]
# Comments:
# * Houses on the coast side tend to have higher prices than others
# * Generally, those in the middle have the lowest prices

# %%
Image.open(pics[1])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=907x553 at 0x214FA5829A0>

# %% [markdown]
# Comments:
# * Sizes of grids in the map represent the number of houses
# * Saturation channel represents the price difference among houses
# * In top 20, some were built around 150 years ago.
# * Out of houses that were built after 2000, only 2014 and 2021 are in top. The ones with highest prices were built before 1970.
#     - Our conjecture is that material plays a significant role in house prices as those built before 1970 were almost made in USA.

# %%
Image.open(pics[2])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=816x537 at 0x214F9389E50>

# %% [markdown]
# Comments:
# * Color channel represents home type
# * Y axis stands for average price per square foot
# * Other than Multi-family ones, of which type dominates the price, the difference between condo, single_family, and townhouse is unsubstantial, followed by apartment and lot
